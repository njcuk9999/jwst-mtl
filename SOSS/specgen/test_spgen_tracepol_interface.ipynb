# %%
# %matplotlib notebook
import spgen as spgen
import numpy as np
import tracepol as tp
import matplotlib.pyplot as plt

os = 2
order = 0

w = np.linspace(0.6,2.9,1000)*10000
pars = tp.get_tracepars('/genesis/jwst/jwst-mtl/SOSS/trace/NIRISS_GR700_trace_extended.csv')
x = spgen.w2p(pars,w,noversample=os,ntrace=order)
#print(x)
y = spgen.ptrace(pars,x,noversample=os,ntrace=order)
#print(y)

plt.figure()
plt.plot(x,y)
plt.show()

wback = spgen.p2w(pars,x,noversample=os,ntrace=order)
#plt.figure()
#plt.plot(w,wback)
#plt.show()
# Out:
# ../trace/tracepol.py:104: RankWarning: Polyfit may be poorly conditioned
#   pars = trace_polynomial(trace, m=m)
# ../trace/tracepol.py:104: RankWarning: Polyfit may be poorly conditioned
#   pars = trace_polynomial(trace, m=m)
# <img src="data:image/png;base64,..." width="640">

# %%
# Note mask will be False for invalid wavelenghts. 
#specpix, spatpix, mask = tp.wavelength_to_pix(w/10000, pars, m=0, frame='sim', oversample=os) 

#plt.figure()
#plt.plot(specpix[mask], spatpix[mask])
#plt.show()

#plt.figure()
#plt.plot(spatpix[mask],y)
#plt.show()


w1 = np.linspace(0.5,5.2,1000)
specpix, spatpix, mask = tp.wavelength_to_pix(w1, pars, m=0, frame='sim', oversample=os) 
w2, mask = tp.specpix_to_wavelength(specpix,pars,m=0,frame='sim',oversample=os)

plt.figure()
plt.plot(w1[mask],w2[mask])
plt.xlim((0.5,1.5))
plt.ylim((0.5,1.5))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
